# %% [markdown]
# <a href="https://colab.research.google.com/github/SharatGupta/DSML-Projects/blob/main/Portifolio_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (20, 6)

# %%
# !gdown 1CCxZMKi3Rb8NiRRwjy4jPvJFKaO0B2pQ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CCxZMKi3Rb8NiRRwjy4jPvJFKaO0B2pQ
# To: /content/Cheatsheet_Tableau.pdf
# 100% 9.37M/9.37M [00:00<00:00, 61.2MB/s]

# %%
# !gdown 1NBk1TFkK4NeKdodR2DxIdBp2Mk1mh4AS
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NBk1TFkK4NeKdodR2DxIdBp2Mk1mh4AS
# To: /content/insurance.csv
# 100% 30.8k/30.8k [00:00<00:00, 45.2MB/s]

# %%
data = pd.read_csv("insurance.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
data.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
for i in data.columns:
  print("unique Values of",i, "are",data[i].nunique())
  print(data[i].value_counts())
  print("******************************************************************")

# %%
for i in data.columns:
  print(i, data[i].nunique(), data[i].min(), data[i].max())
# Out:
# Age 49 18 66
# Diabetes 2 0 1
# BloodPressureProblems 2 0 1
# AnyTransplants 2 0 1
# AnyChronicDiseases 2 0 1
# Height 44 145 188
# Weight 74 51 132
# KnownAllergies 2 0 1
# HistoryOfCancerInFamily 2 0 1
# NumberOfMajorSurgeries 4 0 3
# PremiumPrice 24 15000 40000

# %%
data.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %% [markdown]
# ## Univariate and Bivariate Analysis

# %% [markdown]
# ### Age

# %%
sns.histplot(data["Age"], bins= 10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(data=data, x= "Age", y= "PremiumPrice")
# Out:
# <Axes: xlabel='Age', ylabel='PremiumPrice'>

# %%
data[["Age","PremiumPrice"]].corr()
# Out:
#                   Age  PremiumPrice
# Age           1.00000       0.69754
# PremiumPrice  0.69754       1.00000

# %% [markdown]
# * Higher the Age , more is the Premium

# %% [markdown]
# ### Diabetes

# %% [markdown]
# ### BloodPressureProblems

# %% [markdown]
# ### AnyTransplants

# %% [markdown]
# ### AnyChronicDiseases

# %% [markdown]
# ### KnownAllergies

# %% [markdown]
# ### HistoryOfCancerInFamily

# %% [markdown]
# ### NumberOfMajorSurgeries

# %% [markdown]
# ### Height

# %% [markdown]
# ### Weight

# %%
sns.violinplot(data = data ,y="PremiumPrice", hue="Diabetes")
# Out:
# <Axes: ylabel='PremiumPrice'>

# %%
sns.violinplot(data = data ,y="PremiumPrice", hue="AnyTransplants")
# Out:
# <Axes: ylabel='PremiumPrice'>

# %%
sns.violinplot(data = data ,y="PremiumPrice", hue="BloodPressureProblems")
# Out:
# <Axes: ylabel='PremiumPrice'>

# %%
sns.violinplot(data = data ,y="PremiumPrice", hue="AnyChronicDiseases")
# Out:
# <Axes: ylabel='PremiumPrice'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap = "Greens")
plt.show()

# %% [markdown]
# * Age[0.7] is highly Positively Correlated with PremiumPrice among all
# * Next high Correlated Features are in Order --> "AnyTransplants"[0.29],"NumberOfMajorSurgeries"[0.26],"AnyChronicDiseases"[0.21]

# %% [markdown]
# ## Feature Engineering

# %%
data.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
data["BMI"] = data["Weight"]/((data["Height"]/100)**2)

# %%
data["BMI"].describe()
# Out:
# count    986.000000
# mean      27.460709
# std        5.878671
# min       15.156281
# 25%       23.393392
# 50%       27.156602
# 75%       30.759870
# max       50.000000
# Name: BMI, dtype: float64
