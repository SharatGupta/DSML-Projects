# %% [markdown]
# ## Importing Libraries

# %%
#!pip install gdown

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
from scipy.stats import pearsonr,spearmanr

# %% [markdown]
# ## Loading Datasets & Changing Data Types

# %%
# !gdown 1da0C0bzM_eyXLRRQ56EHz0kDzc1sYOUc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1da0C0bzM_eyXLRRQ56EHz0kDzc1sYOUc
# To: /content/CustomersData.xlsx
# 100% 42.2k/42.2k [00:00<00:00, 58.0MB/s]

# %%
CustomersData = pd.read_excel("CustomersData.xlsx")

# %%
# !gdown 1_-VvRXtcJuX5WpRqVeuGVNa_IfUAgOW8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_-VvRXtcJuX5WpRqVeuGVNa_IfUAgOW8
# To: /content/Discount_Coupon.csv
# 100% 4.92k/4.92k [00:00<00:00, 13.0MB/s]

# %%
Discount_Coupon = pd.read_csv("Discount_Coupon.csv")

# %%
# !gdown 1ctNiusdseIZ6Vrvy600oZmu5C1aTbYzV
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ctNiusdseIZ6Vrvy600oZmu5C1aTbYzV
# To: /content/Marketing_Spend.csv
# 100% 8.67k/8.67k [00:00<00:00, 21.5MB/s]

# %%
Marketing_Spend = pd.read_csv("Marketing_Spend.csv")

# %%
# !gdown 1dkV1EVylOCBXi_qtx4iMCxRKDHcbPVC9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dkV1EVylOCBXi_qtx4iMCxRKDHcbPVC9
# To: /content/Online_Sales.csv
# 100% 5.24M/5.24M [00:00<00:00, 37.1MB/s]

# %%
Online_Sales = pd.read_csv("Online_Sales.csv")

# %%
# !gdown 16Fl-Ddhdj1HhDl1TAmuRg0-RRsUb3X8X
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16Fl-Ddhdj1HhDl1TAmuRg0-RRsUb3X8X
# To: /content/Tax_amount.xlsx
# 100% 9.84k/9.84k [00:00<00:00, 20.8MB/s]

# %%
Tax_amount = pd.read_excel("Tax_amount.xlsx")

# %%
CustomersData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1468 entries, 0 to 1467
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     1468 non-null   int64
#  1   Gender         1468 non-null   object
#  2   Location       1468 non-null   object
#  3   Tenure_Months  1468 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.0+ KB

# %%
CustomersData.head()
# Out:
#    CustomerID Gender    Location  Tenure_Months
# 0       17850      M     Chicago             12
# 1       13047      M  California             43
# 2       12583      M     Chicago             33
# 3       13748      F  California             30
# 4       15100      M  California             49

# %%
Discount_Coupon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             204 non-null    object
#  1   Product_Category  204 non-null    object
#  2   Coupon_Code       204 non-null    object
#  3   Discount_pct      204 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.5+ KB

# %%
Discount_Coupon.head()
# Out:
#   Month Product_Category Coupon_Code  Discount_pct
# 0   Jan          Apparel      SALE10            10
# 1   Feb          Apparel      SALE20            20
# 2   Mar          Apparel      SALE30            30
# 3   Jan         Nest-USA      ELEC10            10
# 4   Feb         Nest-USA      ELEC20            20

# %%
Discount_Coupon.Month.unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'], dtype=object)

# %%
Marketing_Spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           365 non-null    object
#  1   Offline_Spend  365 non-null    int64
#  2   Online_Spend   365 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
Marketing_Spend.head()
# Out:
#        Date  Offline_Spend  Online_Spend
# 0  1/1/2019           4500       2424.50
# 1  1/2/2019           4500       3480.36
# 2  1/3/2019           4500       1576.38
# 3  1/4/2019           4500       2928.55
# 4  1/5/2019           4500       4055.30

# %%
Marketing_Spend.Date = pd.to_datetime(Marketing_Spend["Date"])
Marketing_Spend["Month"] = Marketing_Spend.Date.dt.strftime("%b")

# %%
Marketing_Spend["Total_Spend"] = Marketing_Spend["Offline_Spend"]+ Marketing_Spend["Online_Spend"]

# %%
Marketing_Spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           365 non-null    datetime64[ns]
#  1   Offline_Spend  365 non-null    int64
#  2   Online_Spend   365 non-null    float64
#  3   Month          365 non-null    object
#  4   Total_Spend    365 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 14.4+ KB

# %%
Online_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  object
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 4.0+ MB

# %%
Online_Sales.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679         1/1/2019  GGOENEBJ079499
# 1       17850           16680         1/1/2019  GGOENEBJ079499
# 2       17850           16681         1/1/2019  GGOEGFKQ020399
# 3       17850           16682         1/1/2019  GGOEGAAB010516
# 4       17850           16682         1/1/2019  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status
# 0         1     153.71               6.5          Used
# 1         1     153.71               6.5          Used
# 2         1       2.05               6.5          Used
# 3         5      17.53               6.5      Not Used
# 4         1      16.50               6.5          Used

# %%
Online_Sales.Transaction_Date = pd.to_datetime(Online_Sales["Transaction_Date"])
Online_Sales["Transaction_Month"] = Online_Sales.Transaction_Date.dt.strftime("%b")

# %%
Online_Sales["Transaction_Month"].unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'], dtype=object)

# %%
Online_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Transaction_Month    52924 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 4.4+ MB

# %%
Online_Sales.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status Transaction_Month
# 0         1     153.71               6.5          Used               Jan
# 1         1     153.71               6.5          Used               Jan
# 2         1       2.05               6.5          Used               Jan
# 3         5      17.53               6.5      Not Used               Jan
# 4         1      16.50               6.5          Used               Jan

# %%
Online_Sales[Online_Sales["Transaction_ID"] == 16682]
# Out:
#     CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 3        17850           16682       2019-01-01  GGOEGAAB010516
# 4        17850           16682       2019-01-01  GGOEGBJL013999
# 5        17850           16682       2019-01-01  GGOEGBMJ013399
# 6        17850           16682       2019-01-01  GGOEGDHC018299
# 7        17850           16682       2019-01-01  GGOEGDHG014499
# 8        17850           16682       2019-01-01  GGOEGDWC020199
# 9        13047           16682       2019-01-01  GGOEGGOA017399
# 10       13047           16682       2019-01-01  GGOEGOFH020299
# 11       13047           16682       2019-01-01  GGOEGOXQ016399
# 12       13047           16682       2019-01-01  GGOEYAAB031816
#
#                                   Product_Description Product_Category  \
# 3   Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                     Google Canvas Tote Natural/Navy             Bags
# 5                                           Sport Bag             Bags
# 6                           Google 22 oz Water Bottle        Drinkware
# 7                     Google Infuser-Top Water Bottle        Drinkware
# 8                         Engraved Ceramic Google Mug        Drinkware
# 9                                            Maze Pen           Office
# 10                       Galaxy Screen Cleaning Cloth           Office
# 11                                       Badge Holder           Office
# 12          YouTube Men's Short Sleeve Hero Tee Black          Apparel
#
#     Quantity  Avg_Price  Delivery_Charges Coupon_Status Transaction_Month
# 3          5      17.53               6.5      Not Used               Jan
# 4          1      16.50               6.5          Used               Jan
# 5         15       5.15               6.5          Used               Jan
# 6         15       3.08               6.5      Not Used               Jan
# 7         15      10.31               6.5       Clicked               Jan
# 8          5       9.27               6.5          Used               Jan
# 9         52       0.98               6.5          Used               Jan
# 10        31       1.99               6.5       Clicked               Jan
# 11        31       1.99               6.5       Clicked               Jan
# 12         5      17.53               6.5          Used               Jan

# %%
Tax_amount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_Category  20 non-null     object
#  1   GST               20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 448.0+ bytes

# %%
Tax_amount.head()
# Out:
#   Product_Category   GST
# 0         Nest-USA  0.10
# 1           Office  0.10
# 2          Apparel  0.18
# 3             Bags  0.18
# 4        Drinkware  0.18

# %% [markdown]
# ## Creating Combined Data set

# %% [markdown]
# * Merging Online Sales & Discount Coupon into "Data"

# %%
data = Online_Sales.merge(Discount_Coupon,how = "left", left_on = ["Product_Category","Transaction_Month"],right_on = ["Product_Category","Month"])

# %% [markdown]
# * Merging "data" & Tax_amount

# %%
data = data.merge(Tax_amount, how ="left", on = "Product_Category")

# %% [markdown]
# * Merging "data" & CustomerData

# %%
data = data.merge(CustomersData, how ="left", on = "CustomerID")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Transaction_Month    52924 non-null  object
#  11  Month                52524 non-null  object
#  12  Coupon_Code          52524 non-null  object
#  13  Discount_pct         52524 non-null  float64
#  14  GST                  52924 non-null  float64
#  15  Gender               52924 non-null  object
#  16  Location             52924 non-null  object
#  17  Tenure_Months        52924 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(9)
# memory usage: 7.3+ MB

# %% [markdown]
# * There are 400 Missing values in Discount_pct... we will Fill with Zero as there are no Details for that specific Product Category and Month

# %%
data.drop("Month", axis=1,inplace = True)

# %%
data["Discount_pct"].fillna(0,inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  int64
#  1   Transaction_ID       52924 non-null  int64
#  2   Transaction_Date     52924 non-null  datetime64[ns]
#  3   Product_SKU          52924 non-null  object
#  4   Product_Description  52924 non-null  object
#  5   Product_Category     52924 non-null  object
#  6   Quantity             52924 non-null  int64
#  7   Avg_Price            52924 non-null  float64
#  8   Delivery_Charges     52924 non-null  float64
#  9   Coupon_Status        52924 non-null  object
#  10  Transaction_Month    52924 non-null  object
#  11  Coupon_Code          52524 non-null  object
#  12  Discount_pct         52924 non-null  float64
#  13  GST                  52924 non-null  float64
#  14  Gender               52924 non-null  object
#  15  Location             52924 non-null  object
#  16  Tenure_Months        52924 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(8)
# memory usage: 6.9+ MB

# %%
# 0 --> Monday , 6 --> Sunday
data["weekday"] = data["Transaction_Date"].dt.weekday
data["month"] =data["Transaction_Date"].dt.month
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Calculating Invoice amount

# %%
data.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status Transaction_Month  \
# 0         1     153.71               6.5          Used               Jan
# 1         1     153.71               6.5          Used               Jan
# 2         1       2.05               6.5          Used               Jan
# 3         5      17.53               6.5      Not Used               Jan
# 4         1      16.50               6.5          Used               Jan
#
#   Coupon_Code  Discount_pct   GST Gender Location  Tenure_Months  weekday  \
# 0      ELEC10          10.0  0.10      M  Chicago             12        1
# 1      ELEC10          10.0  0.10      M  Chicago             12        1
# 2       OFF10          10.0  0.10      M  Chicago             12        1
# 3      SALE10          10.0  0.18      M  Chicago             12        1
# 4       AIO10          10.0  0.18      M  Chicago             12        1
#
#    month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
data["Coupon_Status"].value_counts()
# Out:
# Coupon_Status
# Clicked     26926
# Used        17904
# Not Used     8094
# Name: count, dtype: int64

# %% [markdown]
# * Lets Assume "Clicked" means "Used"

# %%
data["Coupon_Status"]= data["Coupon_Status"].transform(lambda x : 1 if x in ["Clicked","Used"] else 0)

# %%
data["Coupon_Status"].value_counts()
# Out:
# Coupon_Status
# 1    44830
# 0     8094
# Name: count, dtype: int64

# %%
data["Discount_pct"] = data["Discount_pct"].transform(lambda x : x/100)

# %% [markdown]
# * Further We have to Correc the delivery charges, it is one time charges but inour data it is being reflelected across all items in a transaction

# %%
A = data.groupby("Transaction_ID")["Delivery_Charges"].count().reset_index()
A.columns = ["Transaction_ID","No_of_Items_in_Transaction"]
A
# Out:
#        Transaction_ID  No_of_Items_in_Transaction
# 0               16679                           1
# 1               16680                           1
# 2               16681                           1
# 3               16682                          10
# 4               16684                           2
# ...               ...                         ...
# 25056           48493                           1
# 25057           48494                           1
# 25058           48495                           1
# 25059           48496                           1
# 25060           48497                           1
#
# [25061 rows x 2 columns]

# %%
data = data.merge(A, on = "Transaction_ID")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CustomerID                  52924 non-null  int64
#  1   Transaction_ID              52924 non-null  int64
#  2   Transaction_Date            52924 non-null  datetime64[ns]
#  3   Product_SKU                 52924 non-null  object
#  4   Product_Description         52924 non-null  object
#  5   Product_Category            52924 non-null  object
#  6   Quantity                    52924 non-null  int64
#  7   Avg_Price                   52924 non-null  float64
#  8   Delivery_Charges            52924 non-null  float64
#  9   Coupon_Status               52924 non-null  int64
#  10  Transaction_Month           52924 non-null  object
#  11  Coupon_Code                 52524 non-null  object
#  12  Discount_pct                52924 non-null  float64
#  13  GST                         52924 non-null  float64
#  14  Gender                      52924 non-null  object
#  15  Location                    52924 non-null  object
#  16  Tenure_Months               52924 non-null  int64
#  17  weekday                     52924 non-null  int32
#  18  month                       52924 non-null  int32
#  19  No_of_Items_in_Transaction  52924 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(6), object(7)
# memory usage: 7.7+ MB

# %%
data["Invoice_value"] = ((data["Quantity"] * data["Avg_Price"] * (1 - (data["Discount_pct"] * data["Coupon_Status"]))) * (1+data["GST"])) + (data["Delivery_Charges"]/data["No_of_Items_in_Transaction"])

# %%
data["Invoice_value"].describe()
# Out:
# count    52924.000000
# mean        85.815973
# std        157.665721
# min          0.813538
# 25%         13.645165
# 50%         33.247660
# 75%        123.447600
# max       8974.075000
# Name: Invoice_value, dtype: float64

# %%
data.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges  Coupon_Status  ... Coupon_Code  \
# 0         1     153.71               6.5              1  ...      ELEC10
# 1         1     153.71               6.5              1  ...      ELEC10
# 2         1       2.05               6.5              1  ...       OFF10
# 3         5      17.53               6.5              0  ...      SALE10
# 4         1      16.50               6.5              1  ...       AIO10
#
#   Discount_pct   GST  Gender Location Tenure_Months  weekday  month  \
# 0          0.1  0.10       M  Chicago            12        1      1
# 1          0.1  0.10       M  Chicago            12        1      1
# 2          0.1  0.10       M  Chicago            12        1      1
# 3          0.1  0.18       M  Chicago            12        1      1
# 4          0.1  0.18       M  Chicago            12        1      1
#
#    No_of_Items_in_Transaction  Invoice_value
# 0                           1       158.6729
# 1                           1       158.6729
# 2                           1         8.5295
# 3                          10       104.0770
# 4                          10        18.1730
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52924 entries, 0 to 52923
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CustomerID                  52924 non-null  int64
#  1   Transaction_ID              52924 non-null  int64
#  2   Transaction_Date            52924 non-null  datetime64[ns]
#  3   Product_SKU                 52924 non-null  object
#  4   Product_Description         52924 non-null  object
#  5   Product_Category            52924 non-null  object
#  6   Quantity                    52924 non-null  int64
#  7   Avg_Price                   52924 non-null  float64
#  8   Delivery_Charges            52924 non-null  float64
#  9   Coupon_Status               52924 non-null  int64
#  10  Transaction_Month           52924 non-null  object
#  11  Coupon_Code                 52524 non-null  object
#  12  Discount_pct                52924 non-null  float64
#  13  GST                         52924 non-null  float64
#  14  Gender                      52924 non-null  object
#  15  Location                    52924 non-null  object
#  16  Tenure_Months               52924 non-null  int64
#  17  weekday                     52924 non-null  int32
#  18  month                       52924 non-null  int32
#  19  No_of_Items_in_Transaction  52924 non-null  int64
#  20  Invoice_value               52924 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(6), object(7)
# memory usage: 8.1+ MB

# %% [markdown]
# * No Duplicates records Found

# %% [markdown]
# # EDA

# %%
data.nunique()
# Out:
# CustomerID                     1468
# Transaction_ID                25061
# Transaction_Date                365
# Product_SKU                    1145
# Product_Description             404
# Product_Category                 20
# Quantity                        151
# Avg_Price                       546
# Delivery_Charges                267
# Coupon_Status                     2
# Transaction_Month                12
# Coupon_Code                      45
# Discount_pct                      4
# GST                               4
# Gender                            2
# Location                          5
# Tenure_Months                    49
# weekday                           7
# month                            12
# No_of_Items_in_Transaction       30
# Invoice_value                 22241
# dtype: int64

# %% [markdown]
# ## Invoice amount

# %%
# Total Invoice Revenue
np.round(data["Invoice_value"].sum(axis = 0))
# Out:
# 4541725.0

# %%
# Average Invoice Revenue per month
np.round(data["Invoice_value"].sum(axis = 0)/12)
# Out:
# 378477.0

# %%
# Invoicevalue per TransactionID
A = data.groupby(["Transaction_ID","Transaction_Month"])["Invoice_value"].sum().reset_index()
A
# Out:
#        Transaction_ID Transaction_Month  Invoice_value
# 0               16679               Jan      158.67290
# 1               16680               Jan      158.67290
# 2               16681               Jan        8.52950
# 3               16682               Jan      743.14840
# 4               16684               Jan      330.26960
# ...               ...               ...            ...
# 25056           48493               Dec       99.90100
# 25057           48494               Dec       46.90792
# 25058           48495               Dec      123.44760
# 25059           48496               Dec      316.50200
# 25060           48497               Dec      267.99160
#
# [25061 rows x 3 columns]

# %%
A["Invoice_value"].describe()
# Out:
# count    25061.000000
# mean       181.226788
# std        396.687141
# min          6.392700
# 25%         54.738880
# 50%        123.447600
# 75%        215.440000
# max      24072.754000
# Name: Invoice_value, dtype: float64

# %%
plt.figure(figsize =(12,3))
sns.boxplot(x= A["Invoice_value"])
# Out:
# <Axes: xlabel='Invoice_value'>

# %%
# Invoice MonthWise
data.groupby("Transaction_Month")["Invoice_value"].sum()
# Out:
# Transaction_Month
# Apr    428991.30294
# Aug    392134.40304
# Dec    450886.14756
# Feb    306722.33194
# Jan    433384.89309
# Jul    399204.22689
# Jun    287366.88697
# Mar    318087.36661
# May    303812.28236
# Nov    477965.24702
# Oct    428983.08952
# Sep    314186.36262
# Name: Invoice_value, dtype: float64

# %%
# Invoice MonthWise
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(data = A, x ="Transaction_Month",y = "Invoice_value", order = Online_Sales["Transaction_Month"].unique(),estimator=np.sum)
# drawing average line
ax.axhline(A["Invoice_value"].sum()/12, color='red', alpha = 0.5)

# %% [markdown]
# ## Average Order Value

# %%
data["Invoice_value"].sum(axis =0)/data["Transaction_ID"].nunique()
# Out:
# 181.22678825904794

# %%
A
# Out:
#        Transaction_ID Transaction_Month  Invoice_value
# 0               16679               Jan      158.67290
# 1               16680               Jan      158.67290
# 2               16681               Jan        8.52950
# 3               16682               Jan      743.14840
# 4               16684               Jan      330.26960
# ...               ...               ...            ...
# 25056           48493               Dec       99.90100
# 25057           48494               Dec       46.90792
# 25058           48495               Dec      123.44760
# 25059           48496               Dec      316.50200
# 25060           48497               Dec      267.99160
#
# [25061 rows x 3 columns]

# %%
# Average Order value Month Wise
A.groupby("Transaction_Month")["Invoice_value"].mean()
# Out:
# Transaction_Month
# Apr    236.619582
# Aug    162.441758
# Dec    167.990368
# Feb    184.328324
# Jan    206.177399
# Jul    191.925109
# Jun    148.127261
# Mar    159.762615
# May    149.366904
# Nov    209.450152
# Oct    201.874395
# Sep    162.622341
# Name: Invoice_value, dtype: float64

# %%
# Average Order value Month Wise
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(data=A, x="Transaction_Month", y="Invoice_value", estimator = np.mean,order = Online_Sales["Transaction_Month"].unique())
#drawing average line
ax.axhline(data["Invoice_value"].sum(axis =0)/data["Transaction_ID"].nunique(), color='red', alpha = 0.5)

# %%
A["Invoice_value"].describe()
# Out:
# count    25061.000000
# mean       181.226788
# std        396.687141
# min          6.392700
# 25%         54.738880
# 50%        123.447600
# 75%        215.440000
# max      24072.754000
# Name: Invoice_value, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(A["Invoice_value"])
# Out:
# <Axes: xlabel='Invoice_value', ylabel='Density'>

# %% [markdown]
# ## No of Orders

# %%
data["Transaction_ID"].nunique()
# Out:
# 25061

# %%
A = data.groupby("Transaction_Month")["Transaction_ID"].nunique().reset_index()
A
# Out:
#    Transaction_Month  Transaction_ID
# 0                Apr            1813
# 1                Aug            2414
# 2                Dec            2684
# 3                Feb            1664
# 4                Jan            2102
# 5                Jul            2080
# 6                Jun            1940
# 7                Mar            1991
# 8                May            2034
# 9                Nov            2282
# 10               Oct            2125
# 11               Sep            1932

# %%
# No of Orders Month Wise
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(data = A, x ="Transaction_Month",y = "Transaction_ID", order = Online_Sales["Transaction_Month"].unique())
#drawing average line
ax.axhline(data["Transaction_ID"].nunique()/12, color='red', alpha = 0.5)

# %% [markdown]
# ## No of Customers

# %%
data["CustomerID"].nunique()
# Out:
# 1468

# %%
A = data.groupby("Transaction_Month")["CustomerID"].nunique().reset_index()
A
# Out:
#    Transaction_Month  CustomerID
# 0                Apr         224
# 1                Aug         300
# 2                Dec         236
# 3                Feb         109
# 4                Jan         215
# 5                Jul         236
# 6                Jun         259
# 7                Mar         208
# 8                May         200
# 9                Nov         188
# 10               Oct         210
# 11               Sep         193

# %%
# Average No of Customer Visting
data.groupby("Transaction_Month")["CustomerID"].nunique().sum(axis=0)/12
# Out:
# 214.83333333333334

# %%
# No of Customer Visiting Each month
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(data = A, x ="Transaction_Month",y = "CustomerID", order = Online_Sales["Transaction_Month"].unique())
#drawing average line
ax.axhline(data.groupby("Transaction_Month")["CustomerID"].nunique().sum(axis=0)/12, color='red', alpha = 0.5)

# %% [markdown]
# ## Customer OnBoarding & Attrition in the Given year

# %%
A = data.groupby("CustomerID").aggregate({"month":[min,max]}).reset_index()
A.columns = ["CustomerID","firstmonth","lastmonth"]
A
# Out:
#       CustomerID  firstmonth  lastmonth
# 0          12346           9          9
# 1          12347           3         11
# 2          12348           6         10
# 3          12350          12         12
# 4          12356           9          9
# ...          ...         ...        ...
# 1463       18259           4          4
# 1464       18260           6         10
# 1465       18269           4          6
# 1466       18277          10         10
# 1467       18283           7         10
#
# [1468 rows x 3 columns]

# %%
A.groupby("firstmonth")["CustomerID"].count()
# Out:
# firstmonth
# 1     215
# 2      96
# 3     177
# 4     163
# 5     112
# 6     137
# 7      94
# 8     135
# 9      78
# 10     87
# 11     68
# 12    106
# Name: CustomerID, dtype: int64

# %%
# No of New Customer Joined in Each Month
fig, ax = plt.subplots(figsize=(15,6))
A.groupby("firstmonth")["CustomerID"].count().plot()
# Out:
# <Axes: xlabel='firstmonth'>

# %%
A.groupby("lastmonth")["CustomerID"].count()
# Out:
# lastmonth
# 1      96
# 2      31
# 3      74
# 4      99
# 5      83
# 6     118
# 7     113
# 8     166
# 9     138
# 10    154
# 11    160
# 12    236
# Name: CustomerID, dtype: int64

# %%
# No of Customer who dropped off in each month
fig, ax = plt.subplots(figsize=(15,6))
A.groupby("lastmonth")["CustomerID"].count().plot()
# Out:
# <Axes: xlabel='lastmonth'>

# %% [markdown]
# ## Cohort Analysis

# %%
A = data.groupby("CustomerID").aggregate({"month":[min,max]}).reset_index()
A.columns = ["CustomerID","firstmonth","lastmonth"]
A
# Out:
#       CustomerID  firstmonth  lastmonth
# 0          12346           9          9
# 1          12347           3         11
# 2          12348           6         10
# 3          12350          12         12
# 4          12356           9          9
# ...          ...         ...        ...
# 1463       18259           4          4
# 1464       18260           6         10
# 1465       18269           4          6
# 1466       18277          10         10
# 1467       18283           7         10
#
# [1468 rows x 3 columns]

# %%
Z = CustomersData.merge(A, on ="CustomerID")

# %%
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
# [1468 rows x 6 columns]

# %%
B=data.groupby("CustomerID").aggregate({"Transaction_Date":[min,max]}).reset_index()
B.columns = ["CustomerID","firsttransaction","Lasttrasaction"]
B
# Out:
#       CustomerID firsttransaction Lasttrasaction
# 0          12346       2019-09-15     2019-09-15
# 1          12347       2019-03-24     2019-11-02
# 2          12348       2019-06-22     2019-10-19
# 3          12350       2019-12-14     2019-12-14
# 4          12356       2019-09-15     2019-09-15
# ...          ...              ...            ...
# 1463       18259       2019-04-05     2019-04-05
# 1464       18260       2019-06-22     2019-10-05
# 1465       18269       2019-04-05     2019-06-20
# 1466       18277       2019-10-23     2019-10-23
# 1467       18283       2019-07-29     2019-10-10
#
# [1468 rows x 3 columns]

# %%
Z = Z.merge(B, on ="CustomerID")

# %%
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
#      firsttransaction Lasttrasaction
# 0          2019-01-01     2019-01-26
# 1          2019-01-01     2019-12-18
# 2          2019-01-01     2019-08-02
# 3          2019-01-01     2019-01-01
# 4          2019-01-01     2019-08-30
# ...               ...            ...
# 1463       2019-12-30     2019-12-31
# 1464       2019-12-31     2019-12-31
# 1465       2019-12-31     2019-12-31
# 1466       2019-12-31     2019-12-31
# 1467       2019-12-31     2019-12-31
#
# [1468 rows x 8 columns]

# %%
C=data.groupby("CustomerID")["Transaction_ID"].nunique()
C
# Out:
# CustomerID
# 12346     1
# 12347    31
# 12348     8
# 12350    11
# 12356    13
#          ..
# 18259     3
# 18260    19
# 18269     2
# 18277     1
# 18283    53
# Name: Transaction_ID, Length: 1468, dtype: int64

# %%
Z = Z.merge(C, on ="CustomerID")

# %%
Z.rename(columns = {'Transaction_ID':'No of Transactions'}, inplace = True)
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
#      firsttransaction Lasttrasaction  No of Transactions
# 0          2019-01-01     2019-01-26                 177
# 1          2019-01-01     2019-12-18                  26
# 2          2019-01-01     2019-08-02                  15
# 3          2019-01-01     2019-01-01                   1
# 4          2019-01-01     2019-08-30                   6
# ...               ...            ...                 ...
# 1463       2019-12-30     2019-12-31                   5
# 1464       2019-12-31     2019-12-31                  14
# 1465       2019-12-31     2019-12-31                   3
# 1466       2019-12-31     2019-12-31                   6
# 1467       2019-12-31     2019-12-31                   2
#
# [1468 rows x 9 columns]

# %%
Z["ActiveDays"] =(Z["Lasttrasaction"]-Z["firsttransaction"])/np.timedelta64(1, 'D')
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
#      firsttransaction Lasttrasaction  No of Transactions  ActiveDays
# 0          2019-01-01     2019-01-26                 177        25.0
# 1          2019-01-01     2019-12-18                  26       351.0
# 2          2019-01-01     2019-08-02                  15       213.0
# 3          2019-01-01     2019-01-01                   1         0.0
# 4          2019-01-01     2019-08-30                   6       241.0
# ...               ...            ...                 ...         ...
# 1463       2019-12-30     2019-12-31                   5         1.0
# 1464       2019-12-31     2019-12-31                  14         0.0
# 1465       2019-12-31     2019-12-31                   3         0.0
# 1466       2019-12-31     2019-12-31                   6         0.0
# 1467       2019-12-31     2019-12-31                   2         0.0
#
# [1468 rows x 10 columns]

# %%
sns.histplot(data = Z, x="ActiveDays", hue = "firstmonth")
# Out:
# <Axes: xlabel='ActiveDays', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data = Z, y="ActiveDays", hue = "firstmonth")
# Out:
# <Axes: ylabel='ActiveDays'>

# %%
Z.groupby("firstmonth").aggregate({"ActiveDays":[min,max]})
# Out:
#            ActiveDays
#                   min    max
# firstmonth
# 1                 0.0  358.0
# 2                 0.0  323.0
# 3                 0.0  284.0
# 4                 0.0  264.0
# 5                 0.0  225.0
# 6                 0.0  191.0
# 7                 0.0  161.0
# 8                 0.0  131.0
# 9                 0.0   95.0
# 10                0.0   68.0
# 11                0.0   31.0
# 12                0.0   24.0

# %%
Z.groupby("firstmonth")["ActiveDays"].mean()
# Out:
# firstmonth
# 1     132.995349
# 2     151.895833
# 3     102.627119
# 4      72.570552
# 5      67.607143
# 6      48.722628
# 7      34.000000
# 8      20.074074
# 9       5.807692
# 10      5.413793
# 11      2.573529
# 12      0.537736
# Name: ActiveDays, dtype: float64

# %%
# Cohort Analysis --> Average Active days for a given cohort
plt.figure(figsize=(12,8))
Z.groupby("firstmonth")["ActiveDays"].mean().plot()
# Out:
# <Axes: xlabel='firstmonth'>

# %% [markdown]
# ## Average time between Orders for Customer

# %%
# If Customer bought only once in agiven year considering customer for frequency of 1 in 365 days
Z["ActiveDays"]= Z["ActiveDays"].transform(lambda x : x if x!= 0.0 else 365)
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
#      firsttransaction Lasttrasaction  No of Transactions  ActiveDays
# 0          2019-01-01     2019-01-26                 177        25.0
# 1          2019-01-01     2019-12-18                  26       351.0
# 2          2019-01-01     2019-08-02                  15       213.0
# 3          2019-01-01     2019-01-01                   1       365.0
# 4          2019-01-01     2019-08-30                   6       241.0
# ...               ...            ...                 ...         ...
# 1463       2019-12-30     2019-12-31                   5         1.0
# 1464       2019-12-31     2019-12-31                  14       365.0
# 1465       2019-12-31     2019-12-31                   3       365.0
# 1466       2019-12-31     2019-12-31                   6       365.0
# 1467       2019-12-31     2019-12-31                   2       365.0
#
# [1468 rows x 10 columns]

# %%
sns.scatterplot(data=Z, x ="ActiveDays", y="No of Transactions")
# Out:
# <Axes: xlabel='ActiveDays', ylabel='No of Transactions'>

# %%
Z["AveOrderDays"] = Z["ActiveDays"]/Z["No of Transactions"]

# %%
Z["AveOrderDays"].describe()
# Out:
# count    1468.000000
# mean       62.238642
# std       101.646725
# min         0.007194
# 25%         5.107724
# 50%        19.210526
# 75%        60.833333
# max       365.000000
# Name: AveOrderDays, dtype: float64

# %%
plt.figure(figsize=(12,3))
sns.kdeplot(x= Z["AveOrderDays"])
# Out:
# <Axes: xlabel='AveOrderDays', ylabel='Density'>

# %% [markdown]
# ## Average ordervalue by Customer

# %%
D = data.groupby("CustomerID")["Invoice_value"].sum()

# %%
Z = Z.merge(D,on ="CustomerID")
Z.rename(columns = {'Invoice_value':'TotalSpent'}, inplace = True)
Z
# Out:
#       CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0          17850      M     Chicago             12           1          1
# 1          13047      M  California             43           1         12
# 2          12583      M     Chicago             33           1          8
# 3          13748      F  California             30           1          1
# 4          15100      M  California             49           1          8
# ...          ...    ...         ...            ...         ...        ...
# 1463       14438      F    New York             41          12         12
# 1464       12956      F     Chicago             48          12         12
# 1465       15781      M  New Jersey             19          12         12
# 1466       14410      F    New York             45          12         12
# 1467       14600      F  California              7          12         12
#
#      firsttransaction Lasttrasaction  No of Transactions  ActiveDays  \
# 0          2019-01-01     2019-01-26                 177        25.0
# 1          2019-01-01     2019-12-18                  26       351.0
# 2          2019-01-01     2019-08-02                  15       213.0
# 3          2019-01-01     2019-01-01                   1       365.0
# 4          2019-01-01     2019-08-30                   6       241.0
# ...               ...            ...                 ...         ...
# 1463       2019-12-30     2019-12-31                   5         1.0
# 1464       2019-12-31     2019-12-31                  14       365.0
# 1465       2019-12-31     2019-12-31                   3       365.0
# 1466       2019-12-31     2019-12-31                   6       365.0
# 1467       2019-12-31     2019-12-31                   2       365.0
#
#       AveOrderDays    TotalSpent
# 0         0.141243  36863.136190
# 1        13.500000   2830.076883
# 2        14.200000   2549.301986
# 3       365.000000      2.245451
# 4        40.166667    867.295240
# ...            ...           ...
# 1463      0.200000    434.956040
# 1464     26.071429   2578.299150
# 1465    121.666667    586.780420
# 1466     60.833333    918.031570
# 1467    182.500000    584.493600
#
# [1468 rows x 12 columns]

# %%
# Customer Wise Average Order Value
Z["AveOrderamount"] = Z["TotalSpent"]/Z["No of Transactions"]

# %%
# Customer Wise Average Order Value
Z["AveOrderamount"].describe()
# Out:
# count    1468.000000
# mean      160.480226
# std       110.510733
# min         1.986667
# 25%       108.585007
# 50%       149.929344
# 75%       188.179001
# max      1716.436147
# Name: AveOrderamount, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x= Z["AveOrderamount"])
# Out:
# <Axes: xlabel='AveOrderamount', ylabel='Density'>

# %% [markdown]
# ## Customer Gender Wise analysis

# %%
Z["Gender"].value_counts()
# Out:
# Gender
# F    934
# M    534
# Name: count, dtype: int64

# %%
plt.pie(x = Z["Gender"].value_counts().reset_index()["count"],
        labels = Z["Gender"].value_counts().reset_index()["Gender"],
        autopct='%.0f%%')
plt.title("Gender feature")
plt.show()

# %%
Z.groupby("Gender")["TotalSpent"].mean()
# Out:
# Gender
# F    3026.656204
# M    3211.287727
# Name: TotalSpent, dtype: float64

# %%
plt.figure(figsize=(4,6))
sns.barplot(data=Z,y="TotalSpent", hue = "Gender", estimator = np.mean)
# Out:
# <Axes: ylabel='TotalSpent'>

# %%
Z.groupby("Gender")["No of Transactions"].mean()
# Out:
# Gender
# F    17.825482
# M    18.692884
# Name: No of Transactions, dtype: float64

# %%
plt.figure(figsize=(4,6))
sns.barplot(data=Z,y="No of Transactions", hue = "Gender", estimator = np.mean)
# Out:
# <Axes: ylabel='No of Transactions'>

# %%
Z.groupby("Gender")["AveOrderDays"].mean()
# Out:
# Gender
# F    63.821742
# M    59.469698
# Name: AveOrderDays, dtype: float64

# %%
plt.figure(figsize=(4,6))
sns.barplot(data=Z,y="AveOrderDays", hue = "Gender", estimator = np.mean)
# Out:
# <Axes: ylabel='AveOrderDays'>

# %%
pd.crosstab(data["Gender"], data["Coupon_Status"], normalize = "index")
# Out:
# Coupon_Status         0         1
# Gender
# F              0.153513  0.846487
# M              0.151981  0.848019

# %% [markdown]
# ## Customer Location Wise analysis

# %%
Z["Location"].value_counts()
# Out:
# Location
# California       464
# Chicago          456
# New York         324
# New Jersey       149
# Washington DC     75
# Name: count, dtype: int64

# %%
plt.pie(x = Z["Location"].value_counts().reset_index()["count"],
        labels = Z["Location"].value_counts().reset_index()["Location"],
        autopct='%.0f%%')
plt.title("Location feature")
plt.show()

# %%
Z.groupby("Location")["TotalSpent"].mean()
# Out:
# Location
# California       3018.866154
# Chicago          3463.779304
# New Jersey       2679.000231
# New York         2816.525291
# Washington DC    3330.160718
# Name: TotalSpent, dtype: float64

# %%
sns.barplot(data=Z,y="TotalSpent", hue = "Location", estimator = np.mean)
# Out:
# <Axes: ylabel='TotalSpent'>

# %%
Z.groupby("Location")["No of Transactions"].mean()
# Out:
# Location
# California       17.366379
# Chicago          20.357456
# New Jersey       15.355705
# New York         17.237654
# Washington DC    18.893333
# Name: No of Transactions, dtype: float64

# %%
sns.barplot(data=Z,y="No of Transactions", hue = "Location", estimator = np.mean)
# Out:
# <Axes: ylabel='No of Transactions'>

# %%
Z.groupby("Location")["AveOrderDays"].mean()
# Out:
# Location
# California       65.887066
# Chicago          61.735516
# New Jersey       62.293613
# New York         59.730125
# Washington DC    53.453651
# Name: AveOrderDays, dtype: float64

# %%
sns.barplot(data=Z,y="AveOrderDays", hue = "Location", estimator = np.mean)
# Out:
# <Axes: ylabel='AveOrderDays'>

# %%
Z["Tenure_Months"].describe()
# Out:
# count    1468.000000
# mean       25.912125
# std        13.959667
# min         2.000000
# 25%        14.000000
# 50%        26.000000
# 75%        38.000000
# max        50.000000
# Name: Tenure_Months, dtype: float64

# %%
pd.crosstab(data["Location"], data["Coupon_Status"], normalize = "index")
# Out:
# Coupon_Status         0         1
# Location
# California     0.148178  0.851822
# Chicago        0.157127  0.842873
# New Jersey     0.158117  0.841883
# New York       0.150273  0.849727
# Washington DC  0.155198  0.844802

# %% [markdown]
# ## RFM Segementation

# %%
Z.head()
# Out:
#    CustomerID Gender    Location  Tenure_Months  firstmonth  lastmonth  \
# 0       17850      M     Chicago             12           1          1
# 1       13047      M  California             43           1         12
# 2       12583      M     Chicago             33           1          8
# 3       13748      F  California             30           1          1
# 4       15100      M  California             49           1          8
#
#   firsttransaction Lasttrasaction  No of Transactions  ActiveDays  \
# 0       2019-01-01     2019-01-26                 177        25.0
# 1       2019-01-01     2019-12-18                  26       351.0
# 2       2019-01-01     2019-08-02                  15       213.0
# 3       2019-01-01     2019-01-01                   1       365.0
# 4       2019-01-01     2019-08-30                   6       241.0
#
#    AveOrderDays    TotalSpent  AveOrderamount
# 0      0.141243  36863.136190      208.266306
# 1     13.500000   2830.076883      108.849111
# 2     14.200000   2549.301986      169.953466
# 3    365.000000      2.245451        2.245451
# 4     40.166667    867.295240      144.549207

# %%
A= Z[["CustomerID","lastmonth","No of Transactions","TotalSpent"]]

# %%
A.describe()
# Out:
#          CustomerID    lastmonth  No of Transactions    TotalSpent
# count   1468.000000  1468.000000         1468.000000   1468.000000
# mean   15314.386240     7.760218           18.141008   3093.817807
# std     1744.000367     3.350833           24.976414   4991.935283
# min    12346.000000     1.000000            1.000000      1.986667
# 25%    13830.500000     5.000000            5.000000    633.429493
# 50%    15300.000000     8.000000           11.000000   1708.350237
# 75%    16882.250000    11.000000           23.000000   3828.725876
# max    18283.000000    12.000000          328.000000  76044.111230

# %%
A["lastmonth"].sort_values()
# Out:
# 0        1
# 136      1
# 135      1
# 134      1
# 132      1
#         ..
# 462     12
# 278     12
# 457     12
# 536     12
# 1467    12
# Name: lastmonth, Length: 1468, dtype: int32

# %%
A["Rtile"] = pd.qcut(A["lastmonth"].sort_values(),5,[1,2,3,4,5])
A["Ftile"] = pd.qcut(A["No of Transactions"].sort_values(),5,[1,2,3,4,5])
A["Mtile"] = pd.qcut(A["TotalSpent"].sort_values(),5,[1,2,3,4,5])
# Out:
# <ipython-input-172-8ed720e78114>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Rtile"] = pd.qcut(A["lastmonth"].sort_values(),5,[1,2,3,4,5])
# <ipython-input-172-8ed720e78114>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Ftile"] = pd.qcut(A["No of Transactions"].sort_values(),5,[1,2,3,4,5])
# <ipython-input-172-8ed720e78114>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Mtile"] = pd.qcut(A["TotalSpent"].sort_values(),5,[1,2,3,4,5])

# %%
A
# Out:
#       CustomerID  lastmonth  No of Transactions    TotalSpent Rtile Ftile  \
# 0          17850          1                 177  36863.136190     1     5
# 1          13047         12                  26   2830.076883     5     4
# 2          12583          8                  15   2549.301986     3     3
# 3          13748          1                   1      2.245451     1     1
# 4          15100          8                   6    867.295240     3     2
# ...          ...        ...                 ...           ...   ...   ...
# 1463       14438         12                   5    434.956040     5     2
# 1464       12956         12                  14   2578.299150     5     3
# 1465       15781         12                   3    586.780420     5     1
# 1466       14410         12                   6    918.031570     5     2
# 1467       14600         12                   2    584.493600     5     1
#
#      Mtile
# 0        5
# 1        4
# 2        4
# 3        1
# 4        2
# ...    ...
# 1463     1
# 1464     4
# 1465     2
# 1466     2
# 1467     2
#
# [1468 rows x 7 columns]

# %%
A["Ftile"] = A["Ftile"].astype("int")
A["Mtile"] = A["Mtile"].astype("int")
A["FMtile"] = ((A["Ftile"]+A["Mtile"])/2)
A["FMtile"] = A["FMtile"].astype("int")
A["FMtile"] = A["FMtile"].astype("category")
# Out:
# <ipython-input-174-9e969411daab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Ftile"] = A["Ftile"].astype("int")
# <ipython-input-174-9e969411daab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["Mtile"] = A["Mtile"].astype("int")
# <ipython-input-174-9e969411daab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["FMtile"] = ((A["Ftile"]+A["Mtile"])/2)
# <ipython-input-174-9e969411daab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["FMtile"] = A["FMtile"].astype("int")
# <ipython-input-174-9e969411daab>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["FMtile"] = A["FMtile"].astype("category")

# %%
A
# Out:
#       CustomerID  lastmonth  No of Transactions    TotalSpent Rtile  Ftile  \
# 0          17850          1                 177  36863.136190     1      5
# 1          13047         12                  26   2830.076883     5      4
# 2          12583          8                  15   2549.301986     3      3
# 3          13748          1                   1      2.245451     1      1
# 4          15100          8                   6    867.295240     3      2
# ...          ...        ...                 ...           ...   ...    ...
# 1463       14438         12                   5    434.956040     5      2
# 1464       12956         12                  14   2578.299150     5      3
# 1465       15781         12                   3    586.780420     5      1
# 1466       14410         12                   6    918.031570     5      2
# 1467       14600         12                   2    584.493600     5      1
#
#       Mtile FMtile
# 0         5      5
# 1         4      4
# 2         4      3
# 3         1      1
# 4         2      2
# ...     ...    ...
# 1463      1      1
# 1464      4      3
# 1465      2      1
# 1466      2      2
# 1467      2      1
#
# [1468 rows x 8 columns]

# %%
def RFM(data):
  if (data["Rtile"] == 5 and data["FMtile"] == 5) or (data["Rtile"] == 5 and data["FMtile"] == 4) or  (data["Rtile"] == 4 and data["FMtile"] == 5):
    return "Champions"
  elif (data["Rtile"] == 5 and data["FMtile"] == 3) or (data["Rtile"] == 4 and data["FMtile"] == 4) or (data["Rtile"] == 3 and data["FMtile"] == 5) or (data["Rtile"] == 3 and data["FMtile"] == 4):
    return "Loyal Customers"
  elif (data["Rtile"] == 5 and data["FMtile"] == 2) or (data["Rtile"] == 4 and data["FMtile"] == 2) or (data["Rtile"] == 3 and data["FMtile"] == 3) or (data["Rtile"] == 4 and data["FMtile"] == 3):
    return "Potential Loyalists"
  elif (data["Rtile"] == 5 and data["FMtile"] == 1):
    return "Recent Customers"
  elif (data["Rtile"] == 4 and data["FMtile"] == 1) or (data["Rtile"] == 3 and data["FMtile"] == 1):
    return "Promising"
  elif (data["Rtile"] == 3 and data["FMtile"] == 2) or (data["Rtile"] == 2 and data["FMtile"] == 3) or (data["Rtile"] == 2 and data["FMtile"] == 2):
    return "Customer Needing Attention"
  elif (data["Rtile"] == 2 and data["FMtile"] == 1):
    return "About to Sleep"
  elif (data["Rtile"] == 2 and data["FMtile"] == 5) or (data["Rtile"] == 2 and data["FMtile"] == 4) or (data["Rtile"] == 1 and data["FMtile"] == 3):
    return "Customer At Risk"
  elif (data["Rtile"] == 1 and data["FMtile"] == 5) or (data["Rtile"] == 1 and data["FMtile"] == 4):
    return "Cant Lose Them"
  elif (data["Rtile"] == 1 and data["FMtile"] == 2):
    return "Hibernating"
  elif (data["Rtile"] == 1 and data["FMtile"] == 1):
    return "Lost"

# %%
A["RFM Segement"] = A.apply(RFM, axis =1)
# Out:
# <ipython-input-177-47a9a936d44a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["RFM Segement"] = A.apply(RFM, axis =1)

# %%
A["RFM Segement"].value_counts(normalize = True)* 100
# Out:
# RFM Segement
# Loyal Customers               15.735695
# Potential Loyalists           14.645777
# Customer Needing Attention    13.828338
# Champions                     12.806540
# Customer At Risk               9.264305
# Promising                      7.697548
# Lost                           7.152589
# About to Sleep                 6.948229
# Cant Lose Them                 4.904632
# Hibernating                    4.632153
# Recent Customers               2.384196
# Name: proportion, dtype: float64

# %%
A["RFM Segement"].value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='RFM Segement'>

# %% [markdown]
# ## Market Spending and its Impact

# %%
Marketing_Spend.head()
# Out:
#         Date  Offline_Spend  Online_Spend Month  Total_Spend
# 0 2019-01-01           4500       2424.50   Jan      6924.50
# 1 2019-01-02           4500       3480.36   Jan      7980.36
# 2 2019-01-03           4500       1576.38   Jan      6076.38
# 3 2019-01-04           4500       2928.55   Jan      7428.55
# 4 2019-01-05           4500       4055.30   Jan      8555.30

# %%
Marketing_Spend.Total_Spend.sum()
# Out:
# 1733546.4700000002

# %%
A= Marketing_Spend.groupby("Month")[["Offline_Spend","Online_Spend","Total_Spend"]].sum().reset_index()
A
# Out:
#    Month  Offline_Spend  Online_Spend  Total_Spend
# 0    Apr          96000      61026.83    157026.83
# 1    Aug          85500      57404.15    142904.15
# 2    Dec         122000      76648.75    198648.75
# 3    Feb          81300      55807.92    137107.92
# 4    Jan          96600      58328.95    154928.95
# 5    Jul          67500      52717.85    120217.85
# 6    Jun          80500      53818.14    134318.14
# 7    Mar          73500      48750.09    122250.09
# 8    May          65500      52759.64    118259.64
# 9    Nov          93000      68144.96    161144.96
# 10   Oct          93500      57724.65    151224.65
# 11   Sep          83000      52514.54    135514.54

# %%
# MarketingSpend MonthWise
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(data = A, x ="Month",y = "Total_Spend", order = Online_Sales["Transaction_Month"].unique(),estimator=np.sum)
# drawing average line
ax.axhline(A["Total_Spend"].sum()/12, color='red', alpha = 0.5)

# %%
# Invoicevalue per month
B = data.groupby(["Transaction_Month"])["Invoice_value"].sum().reset_index()
B.columns = ["Month","Invoice_value"]
B
# Out:
#    Month  Invoice_value
# 0    Apr   428991.30294
# 1    Aug   392134.40304
# 2    Dec   450886.14756
# 3    Feb   306722.33194
# 4    Jan   433384.89309
# 5    Jul   399204.22689
# 6    Jun   287366.88697
# 7    Mar   318087.36661
# 8    May   303812.28236
# 9    Nov   477965.24702
# 10   Oct   428983.08952
# 11   Sep   314186.36262

# %%
C = A.merge(B, on = "Month" )
C
# Out:
#    Month  Offline_Spend  Online_Spend  Total_Spend  Invoice_value
# 0    Apr          96000      61026.83    157026.83   428991.30294
# 1    Aug          85500      57404.15    142904.15   392134.40304
# 2    Dec         122000      76648.75    198648.75   450886.14756
# 3    Feb          81300      55807.92    137107.92   306722.33194
# 4    Jan          96600      58328.95    154928.95   433384.89309
# 5    Jul          67500      52717.85    120217.85   399204.22689
# 6    Jun          80500      53818.14    134318.14   287366.88697
# 7    Mar          73500      48750.09    122250.09   318087.36661
# 8    May          65500      52759.64    118259.64   303812.28236
# 9    Nov          93000      68144.96    161144.96   477965.24702
# 10   Oct          93500      57724.65    151224.65   428983.08952
# 11   Sep          83000      52514.54    135514.54   314186.36262

# %%
C.columns
# Out:
# Index(['Month', 'Offline_Spend', 'Online_Spend', 'Total_Spend',
#        'Invoice_value'],
#       dtype='object')

# %%
C[['Offline_Spend', 'Online_Spend', 'Total_Spend','Invoice_value']].corr()
# Out:
#                Offline_Spend  Online_Spend  Total_Spend  Invoice_value
# Offline_Spend       1.000000      0.879841     0.986571       0.671562
# Online_Spend        0.879841      1.000000     0.945652       0.736638
# Total_Spend         0.986571      0.945652     1.000000       0.712640
# Invoice_value       0.671562      0.736638     0.712640       1.000000

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.scatterplot(data=C,x="Invoice_value",y="Total_Spend",hue = "Month")
# Out:
# <Axes: xlabel='Invoice_value', ylabel='Total_Spend'>

# %% [markdown]
# * lets us do Hypothesis Testing

# %%
# H0: No correlation
# Ha: There is correlation

pearson_coeff, p_value = pearsonr(C["Total_Spend"] ,C["Invoice_value"])
print(pearson_coeff)
print(p_value)
if p_value < 0.05:
    print("Reject H0")
    print("There is correlation")
else:
    print("Fail to reject H0")
    print("There is no correlation")
# Out:
# 0.7126395250835051
# 0.009294863700208537
# Reject H0
# There is correlation

# %% [markdown]
# * from the Hypotheis Testing, there is a Postive Correlation between Marketing Spend and Total Invoice value

# %% [markdown]
# ## Delivery Charges

# %%
data["ItemwiseDeliveryCharge"] = data["Delivery_Charges"]/data["No_of_Items_in_Transaction"]

# %%
data.columns
# Out:
# Index(['CustomerID', 'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'Transaction_Month', 'Coupon_Code',
#        'Discount_pct', 'GST', 'Gender', 'Location', 'Tenure_Months', 'weekday',
#        'month', 'No_of_Items_in_Transaction', 'Invoice_value',
#        'ItemwiseDeliveryCharge'],
#       dtype='object')

# %%
data["ItemwiseDeliveryCharge"].sum()
# Out:
# 220522.14

# %%
data["ItemwiseDeliveryCharge"].sum()/data["Invoice_value"].sum()
# Out:
# 0.04855471485129068

# %% [markdown]
# * 11% of Total Invoice value if of delivery Charges

# %%
# Delivery Charges MonthWise
A = data.groupby("Transaction_Month")["ItemwiseDeliveryCharge"].sum().reset_index()
A
# Out:
#    Transaction_Month  ItemwiseDeliveryCharge
# 0                Apr                15915.50
# 1                Aug                21263.95
# 2                Dec                21241.50
# 3                Feb                16884.96
# 4                Jan                22139.04
# 5                Jul                17254.70
# 6                Jun                15956.97
# 7                Mar                22627.03
# 8                May                16234.95
# 9                Nov                17726.11
# 10               Oct                17448.82
# 11               Sep                15828.61

# %%
# Delivery Charges MonthWise
fig, ax = plt.subplots(figsize=(15,6))
sns.barplot(data = A, x ="Transaction_Month",y = "ItemwiseDeliveryCharge", order = Online_Sales["Transaction_Month"].unique())
# drawing average line
ax.axhline(data["ItemwiseDeliveryCharge"].sum()/12, color='red', alpha = 0.5)

# %%
data["ItemwiseDeliveryCharge"].sum()/12
# Out:
# 18376.845

# %% [markdown]
# * Delivery charges are inirectly Proposationla to no of Orders to some extend

# %%
# Ave Delivery Charges per TransactionID
A = data.groupby("Transaction_ID")[["ItemwiseDeliveryCharge","Invoice_value"]].sum().reset_index()
A
# Out:
#        Transaction_ID  ItemwiseDeliveryCharge  Invoice_value
# 0               16679                    6.50      158.67290
# 1               16680                    6.50      158.67290
# 2               16681                    6.50        8.52950
# 3               16682                    6.50      743.14840
# 4               16684                    6.50      330.26960
# ...               ...                     ...            ...
# 25056           48493                    6.50       99.90100
# 25057           48494                    6.50       46.90792
# 25058           48495                    6.50      123.44760
# 25059           48496                    6.50      316.50200
# 25060           48497                   19.99      267.99160
#
# [25061 rows x 3 columns]

# %%
A["DeliveryChargetoInvoice"] = A["ItemwiseDeliveryCharge"]/A["Invoice_value"]

# %%
A["DeliveryChargetoInvoice"].describe()
# Out:
# count    25061.000000
# mean         0.107730
# std          0.121575
# min          0.000000
# 25%          0.034254
# 50%          0.055961
# 75%          0.139550
# max          0.938571
# Name: DeliveryChargetoInvoice, dtype: float64

# %%
plt.figure(figsize=(10,4))
sns.histplot(A["DeliveryChargetoInvoice"], bins=19)
# Out:
# <Axes: xlabel='DeliveryChargetoInvoice', ylabel='Count'>

# %%
A[["ItemwiseDeliveryCharge","Invoice_value"]].mean()
# Out:
# ItemwiseDeliveryCharge      8.799415
# Invoice_value             181.226788
# dtype: float64

# %% [markdown]
# ## Impact of Discounts on Revenue

# %%
data["Discount_pct"].describe()
# Out:
# count    52924.000000
# mean         0.198024
# std          0.082789
# min          0.000000
# 25%          0.100000
# 50%          0.200000
# 75%          0.300000
# max          0.300000
# Name: Discount_pct, dtype: float64

# %%
data["Discount_pct"].value_counts()
# Out:
# Discount_pct
# 0.2    17830
# 0.1    17470
# 0.3    17224
# 0.0      400
# Name: count, dtype: int64

# %%
A = data.groupby("Discount_pct").aggregate({"Invoice_value": ["mean","sum","count"]}).reset_index()
A.columns =["Discount_pct","Invoice_mean","Invoice_sum","count"]
A
# Out:
#    Discount_pct  Invoice_mean   Invoice_sum  count
# 0           0.0     82.210862  3.288434e+04    400
# 1           0.1     95.950515  1.676256e+06  17470
# 2           0.2     82.478011  1.470583e+06  17830
# 3           0.3     79.075810  1.362002e+06  17224

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=A,x="Discount_pct",y="count")
# Out:
# <Axes: xlabel='Discount_pct', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=A,x="Discount_pct",y="Invoice_mean")
# Out:
# <Axes: xlabel='Discount_pct', ylabel='Invoice_mean'>

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=A,x="Discount_pct",y="Invoice_sum")
# Out:
# <Axes: xlabel='Discount_pct', ylabel='Invoice_sum'>

# %% [markdown]
# * Dicsount_Pct has less impact on Invoice Amount
# * Conversly more Average Revenue value is High for least Discout i.e., 10%
# * So E-Commerce can reduce the discount percentage to increase Profits

# %% [markdown]
# ## Impact of day of week

# %%
A = data.groupby(["Transaction_ID","weekday"])["Invoice_value"].sum().reset_index()
A
# Out:
#        Transaction_ID  weekday  Invoice_value
# 0               16679        1      158.67290
# 1               16680        1      158.67290
# 2               16681        1        8.52950
# 3               16682        1      801.64840
# 4               16684        1      336.76960
# ...               ...      ...            ...
# 25056           48493        1       99.90100
# 25057           48494        1       46.90792
# 25058           48495        1      123.44760
# 25059           48496        1      316.50200
# 25060           48497        1      267.99160
#
# [25061 rows x 3 columns]

# %%
B = A.groupby("weekday").aggregate({"Transaction_ID":"count", "Invoice_value":"sum"}).reset_index()
B
# Out:
#    weekday  Transaction_ID  Invoice_value
# 0        0            2130   370380.30997
# 1        1            2315   406077.81020
# 2        2            4378   863196.07515
# 3        3            4278   882230.95710
# 4        4            4233   905204.20330
# 5        5            3872   715716.50695
# 6        6            3855   735031.60789

# %%
# 0--> Monday , 6--> Sunday
sns.lineplot(data=B,x="weekday",y="Invoice_value")
# Out:
# <Axes: xlabel='weekday', ylabel='Invoice_value'>

# %%
# 0--> Monday , 6--> Sunday
sns.lineplot(data=B,x="weekday",y="Transaction_ID")
# Out:
# <Axes: xlabel='weekday', ylabel='Transaction_ID'>

# %% [markdown]
# ## Products

# %%
A = data.groupby("Product_Category")["Quantity"].sum().sort_values(ascending = False).reset_index()
A
# Out:
#         Product_Category  Quantity
# 0                 Office     88383
# 1                Apparel     32438
# 2              Drinkware     30501
# 3              Lifestyle     24881
# 4               Nest-USA     21430
# 5                   Bags     15273
# 6   Notebooks & Journals      9556
# 7               Headgear      3533
# 8                   Nest      2837
# 9             Housewares      2484
# 10               Bottles      2090
# 11                  Waze      1144
# 12           Accessories      1097
# 13                   Fun       834
# 14                Google       575
# 15           Nest-Canada       469
# 16            Gift Cards       206
# 17             More Bags       144
# 18             Backpacks       113
# 19               Android        45

# %%
plt.figure(figsize=(24,8))
sns.barplot(data=data,x="Product_Category",y="Quantity",estimator = np.sum)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Quantity'>

# %%
A = data.groupby("Product_Description")["Quantity"].sum().sort_values(ascending = False).reset_index()
A.head()
# Out:
#             Product_Description  Quantity
# 0                      Maze Pen     16234
# 1     Google 22 oz Water Bottle     14282
# 2             Google Sunglasses     11452
# 3                     Sport Bag      7321
# 4  Google Metallic Notebook Set      6496

# %%
A.tail()
# Out:
#                                    Product_Description  Quantity
# 399                                     Google Tee Red         3
# 400                            Android 5-Panel Low Cap         3
# 401                Compact Journal with Recycled Pages         1
# 402  Android Women's Short Sleeve Tri-blend Badge T...         1
# 403                Google Women's Colorblock Tee White         1

# %% [markdown]
# ## Market Basket Analysis

# %%
data.head()
# Out:
#    CustomerID  Transaction_ID Transaction_Date     Product_SKU  \
# 0       17850           16679       2019-01-01  GGOENEBJ079499
# 1       17850           16680       2019-01-01  GGOENEBJ079499
# 2       17850           16681       2019-01-01  GGOEGFKQ020399
# 3       17850           16682       2019-01-01  GGOEGAAB010516
# 4       17850           16682       2019-01-01  GGOEGBJL013999
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2              Google Laptop and Cell Phone Stickers           Office
# 3  Google Men's 100% Cotton Short Sleeve Hero Tee...          Apparel
# 4                    Google Canvas Tote Natural/Navy             Bags
#
#    Quantity  Avg_Price  Delivery_Charges  Coupon_Status Transaction_Month  \
# 0         1     153.71               6.5              1               Jan
# 1         1     153.71               6.5              1               Jan
# 2         1       2.05               6.5              1               Jan
# 3         5      17.53               6.5              0               Jan
# 4         1      16.50               6.5              1               Jan
#
#   Coupon_Code  Discount_pct   GST Gender Location  Tenure_Months  weekday  \
# 0      ELEC10           0.1  0.10      M  Chicago             12        1
# 1      ELEC10           0.1  0.10      M  Chicago             12        1
# 2       OFF10           0.1  0.10      M  Chicago             12        1
# 3      SALE10           0.1  0.18      M  Chicago             12        1
# 4       AIO10           0.1  0.18      M  Chicago             12        1
#
#    month  Invoice_value
# 0      1       158.6729
# 1      1       158.6729
# 2      1         8.5295
# 3      1       109.9270
# 4      1        24.0230

# %%
A= data[["Transaction_ID","Product_Description"]]

# %%
A
# Out:
#        Transaction_ID                                Product_Description
# 0               16679  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1               16680  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2               16681              Google Laptop and Cell Phone Stickers
# 3               16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 4               16682                    Google Canvas Tote Natural/Navy
# ...               ...                                                ...
# 52919           48493              Nest Cam Indoor Security Camera - USA
# 52920           48494                            Google Zip Hoodie Black
# 52921           48495       Nest Learning Thermostat 3rd Gen-USA - White
# 52922           48496      Nest Protect Smoke + CO White Wired Alarm-USA
# 52923           48497    Nest Protect Smoke + CO White Battery Alarm-USA
#
# [52924 rows x 2 columns]

# %%
B = A.merge(A,on="Transaction_ID")
B = B[B["Product_Description_x"]>B["Product_Description_y"]]
B
# Out:
#         Transaction_ID                              Product_Description_x  \
# 4                16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 6                16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 7                16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 8                16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 10               16682  Google Men's 100% Cotton Short Sleeve Hero Tee...
# ...                ...                                                ...
# 230587           48489      Nest Protect Smoke + CO White Wired Alarm-USA
# 230588           48489      Nest Protect Smoke + CO White Wired Alarm-USA
# 230594           48491    Nest Protect Smoke + CO White Battery Alarm-USA
# 230597           48491                            Nest Thermostat E - USA
# 230598           48491                            Nest Thermostat E - USA
#
#                                   Product_Description_y
# 4                       Google Canvas Tote Natural/Navy
# 6                             Google 22 oz Water Bottle
# 7                       Google Infuser-Top Water Bottle
# 8                           Engraved Ceramic Google Mug
# 10                         Galaxy Screen Cleaning Cloth
# ...                                                 ...
# 230587       Google Women's Short Sleeve Hero Tee White
# 230588                           Google Trike Tee Black
# 230594            Nest Cam Indoor Security Camera - USA
# 230597            Nest Cam Indoor Security Camera - USA
# 230598  Nest Protect Smoke + CO White Battery Alarm-USA
#
# [84623 rows x 3 columns]

# %%
C= B.groupby(["Product_Description_x","Product_Description_y"])["Transaction_ID"].count().sort_values(ascending=False).reset_index()

# %%
C.head(20)
# Out:
#                                 Product_Description_x  \
# 0              Nest Cam Outdoor Security Camera - USA
# 1                                   Google Sunglasses
# 2   Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 3   Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 4     Nest Protect Smoke + CO White Battery Alarm-USA
# 5     Nest Protect Smoke + CO White Battery Alarm-USA
# 6                                      Windup Android
# 7                                   Google Sunglasses
# 8       Nest Protect Smoke + CO White Wired Alarm-USA
# 9                                   Google Sunglasses
# 10    Nest Protect Smoke + CO White Battery Alarm-USA
# 11                                          Sport Bag
# 12              Google Laptop and Cell Phone Stickers
# 13                                          Sport Bag
# 14                              YouTube Custom Decals
# 15                                  Google Sunglasses
# 16      Nest Protect Smoke + CO White Wired Alarm-USA
# 17              Google Laptop and Cell Phone Stickers
# 18  Google Men's 100% Cotton Short Sleeve Hero Tee...
# 19                         Recycled Paper Journal Set
#
#                                 Product_Description_y  Transaction_ID
# 0               Nest Cam Indoor Security Camera - USA             693
# 1                           Google 22 oz Water Bottle             391
# 2              Nest Cam Outdoor Security Camera - USA             301
# 3               Nest Cam Indoor Security Camera - USA             228
# 4   Nest Learning Thermostat 3rd Gen-USA - Stainle...             226
# 5              Nest Cam Outdoor Security Camera - USA             192
# 6                                   Google Sunglasses             190
# 7               Google Laptop and Cell Phone Stickers             183
# 8   Nest Learning Thermostat 3rd Gen-USA - Stainle...             181
# 9                                    Google Kick Ball             157
# 10              Nest Cam Indoor Security Camera - USA             150
# 11                          Google 22 oz Water Bottle             135
# 12                          Google 22 oz Water Bottle             134
# 13                                  Google Sunglasses             134
# 14              Google Laptop and Cell Phone Stickers             134
# 15                         Foam Can and Bottle Cooler             132
# 16             Nest Cam Outdoor Security Camera - USA             125
# 17                                Google Doodle Decal             123
# 18  Google Men's 100% Cotton Short Sleeve Hero Tee...             120
# 19                                  Google Sunglasses             118
